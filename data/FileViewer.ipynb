# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import Image
from IPython.display import display
import PIL

import json

# %%
with open('train/labels.json') as f:
    train_json = json.load(f)

# %%
for file, text in list(train_json.items())[0:10]:
    display(Image('train/' + file))
    print(text)
# Out:
# He felt a glow of happiness steal over him .
# at the surface . Among other copepods
# co-operated , we made the little side chapel a place
# always used brass screws , which are more expensive . The first
# the slightest effect .
# strong reaction from Sir Roy Welensky to any
# seeking . African delegates are studying
# Martyrs ! " " CRICKET , " says the Oxford
# BUT NONE OF THESE DEDUCTIONS WERE
# power of unbridled ambition .
